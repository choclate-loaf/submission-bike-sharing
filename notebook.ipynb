# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Shinta Khumaira]
# - **Email:** [Banoffe1993@gmail.com]
# - **ID Dicoding:** [cdcc942d6x1050]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana pola perbedaan penggunaan antara pengguna kasual dan terdaftar pada jam sibuk hari kerja tahun 2012?
# - **Pertanyaan 2:** Faktor cuaca apa yang paling signifikan menurunkan jumlah penyewaan di tahun 2011??
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
# Memuat dataset
day_df = pd.read_csv('day.csv')
hour_df = pd.read_csv('hour.csv')

# Menampilkan 5 data teratas
print(day_df.head())
print(hour_df.head())
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
# Mengecek info tipe data dan missing values
print(day_df.info())
print(hour_df.info())

# Mengecek duplikasi
print(f"Duplikat Day: {day_df.duplicated().sum()}")
print(f"Duplikat Hour: {hour_df.duplicated().sum()}")

# Mengecek statistik deskriptif awal
print(day_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data kolom dteday dari object menjadi datetime agar manipulasi waktu lebih akurat
# - Melakukan mapping atau pelabelan pada kolom kategori (seperti weathersit) untuk mempermudah interpretasi saat EDA

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# Mengubah dteday menjadi datetime
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# Membuat label untuk kondisi cuaca agar lebih deskriptif
weather_mapping = {1: 'Clear', 2: 'Misty', 3: 'Light Rain/Snow', 4: 'Heavy Rain'}
day_df['weather_label'] = day_df['weathersit'].map(weather_mapping)

# Memastikan perubahan
print(day_df[['dteday', 'weather_label']].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dteday         731 non-null    datetime64[ns]
#  1   weather_label  731 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 11.6+ KB
# None

# %%
day_df.to_csv("main_data.csv",index=False)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Eksplorasi perbandingan Casual vs Registered berdasarkan jam
hourly_segments = hour_df.groupby('hr')[['casual', 'registered']].mean().reset_index()

# Eksplorasi total penyewaan harian berdasarkan kondisi cuaca
weather_trends = day_df.groupby('weather_label')['cnt'].mean().sort_values(ascending=False).reset_index()

print(hourly_segments.head())
print(weather_trends)
# Out:
#    hr     casual  registered
# 0   0  10.158402   43.739669
# 1   1   6.504144   26.871547
# 2   2   4.772028   18.097902
# 3   3   2.715925    9.011478
# 4   4   1.253945    5.098996
#      weather_label          cnt
# 0            Clear  4876.786177
# 1            Misty  4035.862348
# 2  Light Rain/Snow  1803.285714

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:Bagaimana pola perbedaan penggunaan antara pengguna kasual dan terdaftar pada jam sibuk hari kerja tahun 2012?

# %%
# Filter data: Hari kerja (workingday=1) dan Tahun 2012 (yr=1)
peak_data = hour_df[(hour_df['workingday'] == 1) & (hour_df['yr'] == 1)]
peak_grouped = peak_data.groupby('hr')[['casual', 'registered']].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(peak_grouped['hr'], peak_grouped['registered'], marker='o', label='Registered', color='blue')
plt.plot(peak_grouped['hr'], peak_grouped['casual'], marker='o', label='Casual', color='orange')
plt.title('Rata-rata Penyewaan Jam Sibuk (Hari Kerja, 2012)')
plt.xlabel('Jam (0-23)')
plt.ylabel('Rata-rata Penyewaan')
plt.xticks(range(0, 24))
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:Faktor cuaca apa yang paling signifikan menurunkan jumlah penyewaan di tahun 2011?

# %%
# Filter data: Tahun 2011 (yr=0)
weather_2011 = day_df[day_df['yr'] == 0].groupby('weather_label')['cnt'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=weather_2011, x='weather_label', y='cnt', palette='viridis')
plt.title('Dampak Cuaca Terhadap Total Penyewaan (2011)')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Rata-rata Total Penyewaan')
plt.show()
# Out:
# /tmp/ipykernel_6439/4135777049.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=weather_2011, x='weather_label', y='cnt', palette='viridis')

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Menganalisis 'Recency' (Kapan terakhir transaksi dilakukan dalam dataset)
recent_date = day_df['dteday'].max()
print(f"Data terakhir diperbarui pada: {recent_date}")

# Menganalisis 'Frequency' (Jumlah total penyewaan dalam setahun)
yearly_counts = day_df.groupby('yr')['cnt'].sum()
print(f"Total penyewaan 2011 vs 2012:\n{yearly_counts}")
# Out:
# Data terakhir diperbarui pada: 2012-12-31 00:00:00
# Total penyewaan 2011 vs 2012:
# yr
# 0    1243103
# 1    2049576
# Name: cnt, dtype: int64

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Pengguna terdaftar menggunakan sepeda secara konsisten untuk berangkat dan pulang kerja, sementara pengguna kasual memiliki frekuensi rendah di jam sibuk pagi namun meningkat sedikit di sore hari.
# - **Conclusion pertanyaan 2:** Cuaca ekstrem meerupakan penghambat utama bisnis penyewaan sepeda. Penurunan angka penyewaan sangat drastis saat kondisi cuaca bergeser dari cerah/berkabut ke hujan ringan.
# - ...

# %% [markdown]
# **Rekomendasi Action Item:**
# - Pastikan stok sepeda tersedia di area hunian pada pukul 07:00 dan di area perkantoran pada pukul 16:00 pada hari kerja.
# - Memberikan poin tambahan bagi pengguna terdaftar yang tetap menggunakan penyewaan sepeda saat kondisi cuaca kurang mendukung untuk menjaga loyalitas pengguna.
